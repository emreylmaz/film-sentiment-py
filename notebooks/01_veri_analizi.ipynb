# %% [markdown]
# # IMDB Sentiment Analizi - Veri Analizi
#
# **Proje:** IMDB Film Yorumları Sentiment Analizi
# **Tarih:** 5 Kasım 2025
# **Amaç:** Keşifsel Veri Analizi (EDA)
#
# ---
#
# ## İçindekiler
#
# 1. Veri Yükleme
# 2. Veri İnceleme
# 3. İstatistiksel Analiz
# 4. Metin Analizi
# 5. Görselleştirme
# 6. Sonuçlar ve İçgörüler

# %%
# Import kütüphaneleri
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re

# Ayarlar
pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✓ Kütüphaneler yüklendi")
# Out:
# ✓ Kütüphaneler yüklendi

# %% [markdown]
# ## 1. Veri Yükleme

# %%
# Veriyi yükle
df = pd.read_csv('../data/IMDB Dataset.csv')

print(f"Dataset boyutu: {df.shape}")
print(f"Sütunlar: {list(df.columns)}")
print(f"\n✓ Veri başarıyla yüklendi")
# Out:
# Dataset boyutu: (50000, 2)
# Sütunlar: ['review', 'sentiment']
#
# ✓ Veri başarıyla yüklendi

# %% [markdown]
# ## 2. Veri İnceleme

# %%
from PIL._imaging import display

# İlk 5 satır
display(df.head())

# Veri tipleri ve null değerler
print("\n=== Veri Bilgileri ===")
df.info()

# Null değer kontrolü
print("\n=== Null Değerler ===")
print(df.isnull().sum())

# Sentiment dağılımı
print("\n=== Sentiment Dağılımı ===")
print(df['sentiment'].value_counts())
print(df['sentiment'].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from PIL._imaging import display
#       3 # İlk 5 satır
# ----> 4 display(df.head())
#       6 # Veri tipleri ve null değerler
#       7 print("\n=== Veri Bilgileri ===")
#
# TypeError: function takes exactly 2 arguments (1 given)
